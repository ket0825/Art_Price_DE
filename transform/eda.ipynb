# %% [markdown]
# ## 경로 설정 (커스텀 필요)

# %%
import os
import sys
print(f"현재 노트북 경로: {os.getcwd()}")
os.chdir("/Users/admin/workspace/python/Art_Price_DE")
print(f"변경된 노트북 경로: {os.getcwd()}")
print(f"현재 파이썬 라이브러리 인식 경로: {sys.path}")
sys.path.append('/Users/admin/workspace/python/Art_Price_DE')
print(f"추가된 파이썬 라이브러리 인식 경로: {sys.path[-1]}")
# Out:
# 현재 노트북 경로: /Users/admin/workspace/python/Art_Price_DE
# 변경된 노트북 경로: /Users/admin/workspace/python/Art_Price_DE
# 현재 파이썬 라이브러리 인식 경로: ['/Users/admin/.pyenv/versions/3.10.12/lib/python310.zip', '/Users/admin/.pyenv/versions/3.10.12/lib/python3.10', '/Users/admin/.pyenv/versions/3.10.12/lib/python3.10/lib-dynload', '', '/Users/admin/workspace/python/Art_Price_DE/.venv/lib/python3.10/site-packages', '/Users/admin/workspace/python/Art_Price_DE']
# 추가된 파이썬 라이브러리 인식 경로: /Users/admin/workspace/python/Art_Price_DE

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_json('transformed/Luc_Tuymans/Luc_Tuymans_20250130_023901.json')
df
# Out:
#          artist                                              title  \
# 0   Luc Tuymans                                               Mrs.
# 1   Luc Tuymans  Ohne Titel (Selbsportrait) (Untitled (Self-Por...
# 2   Luc Tuymans                                           Untitled
# 3   Luc Tuymans                                           Untitled
# 4   Luc Tuymans                                             Rumour
# 5   Luc Tuymans                                           Untitled
# 6   Luc Tuymans                                           Untitled
# 7   Luc Tuymans                                           Untitled
# 8   Luc Tuymans                                           Untitled
# 9   Luc Tuymans                                              Shore
# 10  Luc Tuymans                                              Thumb
# 11  Luc Tuymans  (i) Corso (ii) Gross Rosem (iii) Untitled (iv)...
# 12  Luc Tuymans                                       Deal-No Deal
# 13  Luc Tuymans                                            Process
# 14  Luc Tuymans                                              Villa
# 15  Luc Tuymans                                            Maypole
# 16  Luc Tuymans                                            Pigeons
# 17  Luc Tuymans                                            Smoking
# 18  Luc Tuymans                                            Werbung
# 19  Luc Tuymans                                      Self Portrait
# 20  Luc Tuymans                                           Untitled
# 21  Luc Tuymans                                           Untitled
# 22  Luc Tuymans                                           Untitled
# 23  Luc Tuymans                                           Firewood
# 24  Luc Tuymans                                                  3
# 25  Luc Tuymans                            De Wandeling (The Walk)
# 26  Luc Tuymans                                      Self-Portrait
# 27  Luc Tuymans                                  Untitled (Reuter)
# 28  Luc Tuymans                                            Dracula
# 29  Luc Tuymans                                             Yellow
# 30  Luc Tuymans                                              Villa
# 31  Luc Tuymans                                             Vest S
# 32  Luc Tuymans                                           Eyeballs
# 33  Luc Tuymans                                           Untitled
# 34  Luc Tuymans                                           Untitled
# 35  Luc Tuymans                                           Untitled
# 36  Luc Tuymans                                              Villa
# 37  Luc Tuymans                     Sans titre (Tranche de gateau)
# 38  Luc Tuymans                                         Embroidery
# 39  Luc Tuymans                                        Measurement
# 40  Luc Tuymans                                               Bibs
# 41  Luc Tuymans                                             Bijoux
#
#                end_date               estimate_USD  price_USD auction_site  \
# 0   2016-02-11T00:00:00  GBP 1,200,000 - 1,800,000    2144572    Christies
# 1   2015-10-17T00:00:00        GBP 15,000 - 20,000      27075    Christies
# 2   2015-04-15T00:00:00        EUR 60,000 - 80,000     103086    Christies
# 3   2015-02-12T00:00:00      GBP 150,000 - 250,000     241903    Christies
# 4   2013-05-15T00:00:00  USD 1,400,000 - 1,800,000    2699750    Christies
# 5   2013-04-16T00:00:00          EUR 5,000 - 7,000      16374    Christies
# 6   2013-02-14T00:00:00          GBP 2,500 - 3,500      13716    Christies
# 7   2012-09-19T00:00:00          USD 6,000 - 8,000       6875    Christies
# 8   2012-02-15T00:00:00          GBP 6,000 - 8,000       2555    Christies
# 9   2011-11-09T00:00:00      USD 300,000 - 350,000     314500    Christies
# 10  2011-10-15T00:00:00      GBP 100,000 - 150,000     153120    Christies
# 11  2011-10-15T00:00:00        GBP 20,000 - 30,000      35426    Christies
# 12  2011-09-22T00:00:00      USD 600,000 - 800,000    1150000    Christies
# 13  2011-06-01T00:00:00          EUR 2,400 - 3,000       5728    Christies
# 14  2010-11-30T00:00:00        EUR 25,000 - 35,000      33095    Christies
# 15  2009-11-10T00:00:00      USD 500,000 - 700,000     722500    Christies
# 16  2009-10-16T00:00:00      GBP 200,000 - 300,000     629462    Christies
# 17  2009-03-11T00:00:00          USD 7,000 - 9,000       8125    Christies
# 18  2008-12-11T00:00:00          GBP 2,000 - 3,000       3699    Christies
# 19  2008-10-21T00:00:00        GBP 15,000 - 20,000      42827    Christies
# 20  2008-09-09T00:00:00          USD 3,000 - 5,000      10625    Christies
# 21  2007-10-16T00:00:00          GBP 4,000 - 6,000      14041    Christies
# 22  2024-07-01T00:00:00          GBP 5,000 - 7,000       6373    Christies
# 23  2022-11-10T00:00:00            GBP 700 - 1,000       1455    Christies
# 24  2022-10-14T00:00:00        GBP 50,000 - 70,000     419790    Christies
# 25  2022-10-13T00:00:00    GBP 700,000 - 1,000,000    1362200    Christies
# 26  2022-07-01T00:00:00          GBP 3,000 - 5,000       6420    Christies
# 27  2021-10-16T00:00:00          GBP 5,000 - 7,000       6834    Christies
# 28  2019-06-25T00:00:00      GBP 350,000 - 550,000     656988    Christies
# 29  2019-03-07T00:00:00       GBP 80,000 - 120,000     131566    Christies
# 30  2018-10-05T00:00:00        GBP 10,000 - 15,000      16175    Christies
# 31  2018-04-24T00:00:00        EUR 20,000 - 30,000      73640    Christies
# 32  2017-10-07T00:00:00        GBP 60,000 - 80,000     180299    Christies
# 33  2017-04-13T00:00:00          USD 2,200 - 2,800       2375    Christies
# 34  2017-04-05T00:00:00          GBP 6,000 - 8,000       6246    Christies
# 35  2017-03-08T00:00:00        GBP 18,000 - 25,000      26016    Christies
# 36  2016-05-31T00:00:00          EUR 2,000 - 3,000       9026    Christies
# 37  2016-05-31T00:00:00         EUR 7,000 - 10,000       6666    Christies
# 38  2016-05-31T00:00:00      EUR 200,000 - 300,000     348298    Christies
# 39  2016-05-11T00:00:00      USD 300,000 - 500,000     425000    Christies
# 40  2016-04-21T00:00:00      EUR 100,000 - 150,000     219808    Christies
# 41  2016-02-12T00:00:00      GBP 120,000 - 180,000     352266    Christies
#
#       year                                       artwork_type  edition  \
# 0   1999.0                                      oil on canvas      NaN
# 1      NaN   watercolour, graphite and paper collage on paper      NaN
# 2   1978.0           pencil, watercolour and gouache on paper      NaN
# 3   2000.0                                      oil on canvas      NaN
# 4   2001.0                                      oil on canvas      NaN
# 5   1979.0              pencil and watercolour on brown paper      NaN
# 6   1997.0         watercolour, gouache and graphite on paper      NaN
# 7   1994.0                      gouache and graphite on paper      NaN
# 8   1985.0          watercolour on wallpaper collage on board      NaN
# 9   2011.0                                      oil on canvas      NaN
# 10  1993.0                                      oil on canvas      NaN
# 11  1989.0                       (i-iii) watercolour on paper      NaN
# 12  2011.0                                      oil on canvas      NaN
# 13  1990.0  pencil and coloured crayon on paper laid down ...      NaN
# 14  1987.0                    pencil and watercolour on paper      NaN
# 15  2000.0                                      oil on canvas      NaN
# 16  2001.0                                      oil on canvas      NaN
# 17  1990.0               watercolor on paper mounted on paper      NaN
# 18  1989.0            gouache, ink and paper collage on paper      NaN
# 19  1982.0        gouache, acrylic, ink and graphite on paper      NaN
# 20  1993.0            acrylic, ink and photo collage on paper      NaN
# 21  1986.0  (i) gouache, felt-tip pen, ink and staple on p...      NaN
# 22  2014.0          <i>untitled </i><br> watercolour on paper      NaN
# 23  1994.0                               screenprint on paper      NaN
# 24  1978.0                                   oil on cardboard      NaN
# 25  1991.0                                      oil on canvas      NaN
# 26     NaN                     graphite and charcoal on paper      NaN
# 27  1986.0           felt-tip pen and ball-point pen on paper      NaN
# 28  2001.0                                      oil on canvas      NaN
# 29  1986.0                                      oil on canvas      NaN
# 30  1987.0                  watercolour and graphite on paper      NaN
# 31  1989.0                                    oil on masonite      NaN
# 32  2003.0                                      oil on canvas      NaN
# 33  1978.0                          ink and graphite on paper      NaN
# 34  1996.0             watercolour and colour pencil on paper      NaN
# 35  1980.0                  watercolour and graphite on paper      NaN
# 36     NaN                                            Unknown      NaN
# 37     NaN                gouache et mine de plomb sur papier      NaN
# 38  1993.0                                    huile sur toile      NaN
# 39  2009.0                                      oil on canvas      NaN
# 40  1995.0                                      oil on canvas      NaN
# 41  2015.0                                      oil on canvas      NaN
#
#     height_cm  width_cm
# 0      217.00    134.00
# 1       54.70     36.40
# 2       45.50     37.00
# 3      100.01     84.77
# 4      118.00     67.00
# 5       49.00     39.00
# 6       11.11     14.92
# 7       13.30     10.40
# 8       55.80     50.10
# 9      111.76    101.92
# 10      45.72     53.66
# 11      27.00     21.00
# 12     227.65    135.57
# 13      28.50     20.00
# 14      35.00     49.00
# 15     234.00    115.89
# 16     128.90    156.00
# 17      59.00     40.00
# 18      15.56     11.11
# 19      76.00     52.00
# 20      30.40     21.50
# 21      21.00     16.50
# 22      39.69     28.89
# 23      35.56     27.62
# 24      80.01     80.01
# 25      37.15     48.26
# 26      36.00     27.00
# 27      21.00     27.00
# 28     160.02    174.94
# 29     100.00    120.50
# 30      34.00     49.00
# 31      40.00     40.00
# 32      40.64     30.16
# 33      20.64     16.19
# 34      27.00     21.00
# 35      50.00     40.00
# 36      29.50     20.50
# 37      21.00     27.00
# 38     127.00     94.50
# 39     172.09    188.91
# 40      81.50     86.00
# 41      53.40    116.20
